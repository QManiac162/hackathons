# %%
# !pip uninstall -y tensorflow
# !pip install tensorflow-cpu
# !pip install surya-ocr
# Out:
# Found existing installation: tensorflow 2.15.0
# Uninstalling tensorflow-2.15.0:
#   Successfully uninstalled tensorflow-2.15.0
# Collecting tensorflow-cpu
#   Downloading tensorflow_cpu-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (18.1.1)
# Collecting ml-dtypes<0.5.0,>=0.3.1 (from tensorflow-cpu)
#   Downloading ml_dtypes-0.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (1.66.1)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow-cpu)
#   Downloading tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.2.0 (from tensorflow-cpu)
#   Downloading keras-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow-cpu) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow-cpu) (13.8.1)
# Collecting namex (from keras>=3.2.0->tensorflow-cpu)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.2.0->tensorflow-cpu)
#   Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 838.6 kB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow-cpu) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow-cpu) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow-cpu) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow-cpu) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow-cpu) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow-cpu) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow-cpu) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-cpu) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow-cpu) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow-cpu) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-cpu) (0.1.2)
# Downloading tensorflow_cpu-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (221.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.2/221.2 MB 4.6 MB/s eta 0:00:00
# Downloading keras-3.5.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.2 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 59.3 MB/s eta 0:00:00
# Downloading tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 72.6 MB/s eta 0:00:00
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.7/347.7 kB 17.9 MB/s eta 0:00:00
# Installing collected packages: namex, optree, ml-dtypes, tensorboard, keras, tensorflow-cpu
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# Successfully installed keras-3.5.0 ml-dtypes-0.4.1 namex-0.0.8 optree-0.12.1 tensorboard-2.17.1 tensorflow-cpu-2.17.0
# Requirement already satisfied: surya-ocr in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (1.2.0)
# Requirement already satisfied: ftfy<7.0.0,>=6.1.3 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (6.2.3)
# Requirement already satisfied: opencv-python<5.0.0.0,>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (4.10.0.84)
# Requirement already satisfied: pillow<11.0.0,>=10.2.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (2.9.1)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (2.5.2)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.25.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (4.30.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (1.0.1)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (0.9.0)
# Requirement already satisfied: torch<3.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (2.4.0+cpu)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from surya-ocr) (4.44.2)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy<7.0.0,>=6.1.3->surya-ocr) (0.2.13)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python<5.0.0.0,>=4.9.0.80->surya-ocr) (1.26.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.3->surya-ocr) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.3->surya-ocr) (2.23.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.3->surya-ocr) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (3.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.3.0->surya-ocr) (2024.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (0.24.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->surya-ocr) (4.66.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=2.3.0->surya-ocr) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.41.0->surya-ocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.41.0->surya-ocr) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.41.0->surya-ocr) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.41.0->surya-ocr) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<3.0.0,>=2.3.0->surya-ocr) (1.3.0)

# %%
import os
import pandas as pd
from PIL import Image
from surya.ocr import run_ocr
from surya.model.detection.model import load_model as load_det_model, load_processor as load_det_processor
from surya.model.recognition.model import load_model as load_rec_model
from surya.model.recognition.processor import load_processor as load_rec_processor
import re

# %%
det_processor, det_model = load_det_processor(), load_det_model()
rec_model, rec_processor = load_rec_model(), load_rec_processor()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/675 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/811 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/154M [00:00<?, ?B/s]
# Loaded detection model vikp/surya_det3 on device cpu with dtype torch.float32
# config.json:   0%|          | 0.00/8.05k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/941M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]
# Loaded recognition model vikp/surya_rec2 on device cpu with dtype torch.float32
# preprocessor_config.json:   0%|          | 0.00/556 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Abbreviation map
unit_abbreviation_map = {
    'cm': 'centimetre', 'mm': 'millimetre', 'm': 'metre', 'in': 'inch', 'ft': 'foot', 'yd': 'yard',
    'g': 'gram', 'kg': 'kilogram', 'mg': 'milligram', 'oz': 'ounce', 'lb': 'pound', 't': 'ton',
    'kV': 'kilovolt', 'V': 'volt', 'mV': 'millivolt',
    'kW': 'kilowatt', 'W': 'watt',
    'cl': 'centilitre', 'ml': 'millilitre', 'l': 'litre', 'fl oz': 'fluid ounce', 'gal': 'gallon',
    'pt': 'pint', 'qt': 'quart', 'cu ft': 'cubic foot', 'cu in': 'cubic inch'
}

# Entity-unit map
entity_unit_map = {
    'width': {'centimetre', 'foot', 'inch', 'metre', 'millimetre', 'yard'},
    'depth': {'centimetre', 'foot', 'inch', 'metre', 'millimetre', 'yard'},
    'height': {'centimetre', 'foot', 'inch', 'metre', 'millimetre', 'yard'},
    'item_weight': {'gram', 'kilogram', 'microgram', 'milligram', 'ounce', 'pound', 'ton'},
    'maximum_weight_recommendation': {'gram', 'kilogram', 'microgram', 'milligram', 'ounce', 'pound', 'ton'},
    'voltage': {'kilovolt', 'millivolt', 'volt'},
    'wattage': {'kilowatt', 'watt'},
    'item_volume': {'centilitre', 'cubic foot', 'cubic inch', 'cup', 'decilitre', 'fluid ounce',
                    'gallon', 'imperial gallon', 'litre', 'microlitre', 'millilitre', 'pint', 'quart'}
}

# %%
# Function to get all relevant units and abbreviations for an entity
def get_entity_units(entity_name):
    if entity_name not in entity_unit_map:
        return set()

    units = entity_unit_map[entity_name]
    # Find abbreviations that map to these units
    abbreviations = {abbr for abbr, full in unit_abbreviation_map.items() if full in units}
    # Combine full units and their abbreviations
    return units.union(abbreviations)

# Function to extract entity values with abbreviation handling
def extract_entity_values(text, entity_name):
    valid_units = get_entity_units(entity_name)
    if not valid_units:
        return []

    # Build regex pattern to match numbers followed by valid units or their abbreviations
    # Sort by length to handle multi-word units like 'fluid ounce'
    sorted_units = sorted(valid_units, key=lambda x: -len(x))
    pattern = r'(\d+(?:\.\d+)?)\s*(' + '|'.join(map(re.escape, sorted_units)) + r')\b'

    # Find all matches
    matches = re.findall(pattern, text)

    extracted = []
    for value, unit in matches:
        # Convert abbreviation to full unit name if necessary
        full_unit = unit_abbreviation_map.get(unit, unit)
        extracted.append((float(value), full_unit))

    return extracted

# Function to select the appropriate value based on entity rules
def select_entity_value(extracted_values, entity_name):
    if not extracted_values:
        return ""

    # Extract numerical values
    values = [val for val, unit in extracted_values]

    if entity_name == 'height':
        selected = max(values)
    elif entity_name == 'width':
        if len(values) >= 2:
            sorted_vals = sorted(values, reverse=True)
            selected = sorted_vals[1]  # Second maximum
        else:
            selected = max(values)
    elif entity_name == 'depth':
        selected = min(values)
    elif entity_name == 'maximum_weight_recommendation':
        selected = max(values)
    else:
        selected = values[0]  # Default to first value

    # Find the corresponding unit
    for val, unit in extracted_values:
        if val == selected:
            return f"{val} {unit}"

    return ""  # Fallback in case something goes wrong

# Function to process all texts for a specific entity
def process_texts(texts, entity_name):
    all_extracted = []
    for text in texts:
        extracted = extract_entity_values(text, entity_name)
        all_extracted.extend(extracted)

    selected_value = select_entity_value(all_extracted, entity_name)
    return selected_value

# %%
# Predictor function integrating OCR and entity extraction
from io import BytesIO
import requests

def predictor(image_link, category_id, entity_name):

    # Extract image name from the link
    image_name = os.path.basename(image_link)

    try:
        # Load the image
        response = requests.get(image_link)

        # Open the image using PIL
        image = Image.open(BytesIO(response.content))
        # Run OCR
        predictions = run_ocr([image], [["en"]], det_model, det_processor, rec_model, rec_processor)
        # Extract texts from OCR predictions
        extracted_texts = [text_line.text for result in predictions for text_line in result.text_lines]
        # Process texts to extract the entity value
        prediction = process_texts(extracted_texts, entity_name)
        return prediction

    except FileNotFoundError:
        print(f"Image {image_name} not found in the folder.")
        return None

# %%
# Main execution
if __name__ == "__main__":

    # Load test CSV
    output_filename = '/content/drive/MyDrive/template/dataset/t50k-60k.csv'
    test = pd.read_csv('/content/drive/MyDrive/template/dataset/test.csv')
    test_subset = test.iloc[50000:60000]

# Write headers to the CSV file (to create the file)
    with open(output_filename, mode='w') as f:
        f.write("index,prediction\n")

# Run predictions and append each result to the CSV file
    for index, row in test_subset.iterrows():
        prediction = predictor(row['image_link'], row['group_id'], row['entity_name'])
        with open(output_filename, mode='a') as f:
          f.write(f"{row['index']},{prediction}\n")
# Out:
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.44s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:07<00:00,  7.11s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.05it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.54s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.24s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.61s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.83s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.52s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.83s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:05<00:00,  5.46s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:05<00:00,  5.61s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.59s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.63s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.39s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.05it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:04<00:00,  4.19s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.92s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.91s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.75s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.81s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.76s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:03<00:00,  3.34s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:07<00:00,  7.50s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:05<00:00,  5.16s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:04<00:00,  4.82s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.51it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.57it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# Recognizing Text: 100%|██████████| 6/6 [00:46<00:00,  7.73s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
# Recognizing Text: 100%|██████████| 6/6 [00:49<00:00,  8.23s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.07it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.07it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.23s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.14s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.48s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.84s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.28it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.17s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.05it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.80s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:04<00:00,  4.18s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.14s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.61it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.14s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.61it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.25s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.17s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.07s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.47it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.36it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.39it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.29it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.80it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.70it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.07s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.02s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.56it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.07s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.36it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.30s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.21s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.06s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.25s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.18s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.89s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.05s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.25s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.68s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.02s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.84s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.28it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:03<00:00,  3.01s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:04<00:00,  4.01s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.29s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.09s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.02s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.86it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.83it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.07s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:03<00:00,  3.59s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.17s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:03<00:00,  3.42s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.40s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.17s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.28it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:04<00:00,  4.47s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.05s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.33it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.06s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.33it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:04<00:00,  4.50s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:04<00:00,  4.28s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.07it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.50s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.07s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.07s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.33s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.55s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.71it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.70it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.54s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.43s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.43s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.31s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.76s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.06s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.64s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.12s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.81s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.28s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.87s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.07s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:03<00:00,  3.67s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.92s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.81s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.04s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.81s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:04<00:00,  4.37s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:04<00:00,  4.10s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.13it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.71it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.69it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.09s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.74s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.16s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.04s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.11s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.24s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.11s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.06s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.02s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.55it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.17s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.25s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.20s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.89s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.21s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.36s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.65s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:02<00:00,  2.11s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.17s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:05<00:00,  5.14s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.22s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.66it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]
# Detecting bboxes: 100%|██████████| 1/1 [00:02<00:00,  2.17s/it]
# Recognizing Text: 100%|██████████| 1/1 [00:03<00:00,  3.43s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# Recognizing Text: 100%|██████████| 2/2 [00:14<00:00,  7.10s/it]
# Detecting bboxes: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
# Recognizing Text:   0%|          | 0/1 [00:00<?, ?it/s]
